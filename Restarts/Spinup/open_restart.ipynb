# %%
# Import modules
import numpy as np
import xarray as xr
import pandas as pd
import matplotlib as mpl
pd.set_option('display.max_colwidth', None)
pd.set_option('display.max_rows', None)

# %%
# Import files 
v14_1_1_file = f"/home/ucfacb0/rundirs/Rockets/gc_4x5_47L_merra2_fullchem_main/Restarts/Spinup/GEOSChem.Restart.20190801_0000z.nc4"
v14_3_0_file = f"/home/ucfacb0/rundirs/Rockets/gc_4x5_47L_merra2_fullchem_main/Restarts/Spinup/GEOSChem.Restart.fullchem.20190701_0000z_sample.nc4"
ds_v14_1_1 = xr.open_dataset(v14_1_1_file)
ds_v14_3_0 = xr.open_dataset(v14_3_0_file)
ds_v14_3_0
# Out:
# <xarray.Dataset>
# Dimensions:              (time: 1, lev: 72, ilev: 73, lat: 46, nb: 2, lon: 72)
# Coordinates:
#   * time                 (time) datetime64[ns] 2019-07-01
#   * lev                  (lev) float64 0.9925 0.9775 ... 2.635e-05 1.5e-05
#   * ilev                 (ilev) float64 1.0 0.985 0.97 ... 3.27e-05 2e-05 1e-05
#   * lat                  (lat) float64 -89.0 -86.0 -82.0 ... 82.0 86.0 89.0
#   * lon                  (lon) float64 -180.0 -175.0 -170.0 ... 170.0 175.0
# Dimensions without coordinates: nb
# Data variables: (12/347)
#     lat_bnds             (lat, nb) float64 ...
#     lon_bnds             (lon, nb) float64 ...
#     hyam                 (lev) float64 ...
#     hybm                 (lev) float64 ...
#     hyai                 (ilev) float64 ...
#     hybi                 (ilev) float64 ...
#     ...                   ...
#     SpeciesRst_ASOA1     (time, lev, lat, lon) float32 ...
#     SpeciesRst_ALK4      (time, lev, lat, lon) float32 ...
#     SpeciesRst_ALD2      (time, lev, lat, lon) float32 ...
#     SpeciesRst_AERI      (time, lev, lat, lon) float32 ...
#     SpeciesRst_ACTA      (time, lev, lat, lon) float32 ...
#     SpeciesRst_ACET      (time, lev, lat, lon) float32 ...
# Attributes:
#     title:                           GEOS-Chem diagnostic collection: Restart
#     history:
#     format:                          NetCDF-4
#     conventions:                     COARDS
#     ProdDateTime:
#     reference:                       www.geos-chem.org; wiki.geos-chem.org
#     contact:                         GEOS-Chem Support Team (geos-chem-suppor...
#     simulation_start_date_and_time:  2019-06-01 00:00:00z
#     simulation_end_date_and_time:    2019-07-01 00:00:00z

# %%
# Look for missing items in v14_1_1
varnames_v14_1_1 = list(ds_v14_1_1.data_vars.keys())
varnames_v14_3_0 = list(ds_v14_3_0.data_vars.keys())

varname_list, normal_list, alumina_list, diff_list, diffpercent_list = [],[],[],[],[]
for varname in varnames_v14_3_0:
    if varname not in varnames_v14_1_1:
        varname_list.append(varname)
        
print(varname_list)
# Out:
# []

# %%
ds_v14_1_1.close()

# %%
spinup_file = f"/home/ucfacb0/rundirs/Rockets/gc_4x5_47L_merra2_fullchem_main/Restarts/Spinup/GEOSChem.Restart.20190901_0000z.nc4"
ds_spinup = xr.open_dataset(spinup_file)
ds_spinup
# Out:
# <xarray.Dataset>
# Dimensions:              (time: 1, lev: 47, ilev: 48, lat: 46, nb: 2, lon: 72)
# Coordinates:
#   * time                 (time) datetime64[ns] 2019-09-01
#   * lev                  (lev) float64 0.9925 0.9775 ... 0.0001387 3.8e-05
#   * ilev                 (ilev) float64 1.0 0.985 0.97 ... 6.6e-05 1e-05
#   * lat                  (lat) float64 -89.0 -86.0 -82.0 ... 82.0 86.0 89.0
#   * lon                  (lon) float64 -180.0 -175.0 -170.0 ... 170.0 175.0
# Dimensions without coordinates: nb
# Data variables: (12/332)
#     lat_bnds             (lat, nb) float64 ...
#     lon_bnds             (lon, nb) float64 ...
#     hyam                 (lev) float64 ...
#     hybm                 (lev) float64 ...
#     hyai                 (ilev) float64 ...
#     hybi                 (ilev) float64 ...
#     ...                   ...
#     SpeciesRst_AONITA    (time, lev, lat, lon) float32 ...
#     SpeciesRst_ALK4      (time, lev, lat, lon) float32 ...
#     SpeciesRst_ALD2      (time, lev, lat, lon) float32 ...
#     SpeciesRst_AERI      (time, lev, lat, lon) float32 ...
#     SpeciesRst_ACTA      (time, lev, lat, lon) float32 ...
#     SpeciesRst_ACET      (time, lev, lat, lon) float32 ...
# Attributes:
#     title:                           GEOS-Chem diagnostic collection: Restart
#     history:
#     format:                          NetCDF-4
#     conventions:                     COARDS
#     ProdDateTime:
#     reference:                       www.geos-chem.org; wiki.geos-chem.org
#     contact:                         GEOS-Chem Support Team (geos-chem-suppor...
#     simulation_start_date_and_time:  2019-08-01 00:00:00z
#     simulation_end_date_and_time:    2020-01-01 00:00:00z

# %%
# Import final spinup file
spinup_file = f"/home/ucfacb0/rundirs/Rockets/gc_4x5_47L_merra2_fullchem_main/Restarts/Spinup/GEOSChem.Restart.20200101_0000z.nc4"
ds_spinup = xr.open_dataset(spinup_file)
new_species = ['SpeciesRst_PSO4AQ', 'SpeciesRst_PH2SO4', 'SpeciesRst_TSOG3', 'SpeciesRst_TSOG2',
               'SpeciesRst_TSOG1', 'SpeciesRst_TSOG0', 'SpeciesRst_TSOA3', 'SpeciesRst_TSOA2',
               'SpeciesRst_TSOA1', 'SpeciesRst_TSOA0', 'SpeciesRst_FURA', 'SpeciesRst_BUTDI',
               'SpeciesRst_ASOG3', 'SpeciesRst_ASOG2', 'SpeciesRst_ASOG1', 'SpeciesRst_ASOAN',
               'SpeciesRst_ASOA3', 'SpeciesRst_ASOA2', 'SpeciesRst_ASOA1']

varnames = list(ds_spinup.data_vars.keys())
varname_list, sample_list, spinup_list, diff_list, diffpercent_list,new_list = [],[],[],[],[],[]
for varname in varnames:
    varname_list.append(varname)
    sample_list.append(np.sum(ds_v14_3_0[varname].values))
    spinup_list.append(np.sum(ds_spinup[varname].values))
    diff_list.append(np.abs(np.sum(ds_spinup[varname].values)-np.sum(ds_v14_3_0[varname].values)))
    diffpercent_list.append((np.abs(np.sum(ds_spinup[varname].values)-np.sum(ds_v14_3_0[varname].values)))/(np.sum(ds_v14_3_0[varname].values)*100))
    if varname in new_species:
        new_list.append("1")
    else:
        new_list.append("0")
        

data = pd.DataFrame({'varname': varname_list, 'sample_list': sample_list, 'spinup_list': spinup_list, 
                     'diff_list': diff_list, 'diffpercent_list': diffpercent_list, 'new_list': new_list},
                    columns=['varname', 'sample_list', 'spinup_list', 'diff_list', 'diffpercent_list', 'new_list'])

def make_pretty(styler):
    styler.background_gradient(axis=1, vmin=0, vmax=1, cmap="YlGnBu",subset="diffpercent_list")
    styler.format('{:.4e}', subset=['sample_list', 'spinup_list', 'diff_list'])
    styler.format('{:.4e}', subset=['diffpercent_list'])
    return styler


#data.to_csv(f"{file}.csv",sep=',')
data = data.sort_values(["new_list"], ascending=False)
data[data["diff_list"] != None].style.pipe(make_pretty)
# Out:
# /tmp/ipykernel_149180/1763792191.py:17: RuntimeWarning: invalid value encountered in scalar divide
#   diffpercent_list.append((np.abs(np.sum(ds_spinup[varname].values)-np.sum(ds_v14_3_0[varname].values)))/(np.sum(ds_v14_3_0[varname].values)*100))
# <style type="text/css">
# #T_65761_row0_col4, #T_65761_row1_col4, #T_65761_row5_col4, #T_65761_row6_col4, #T_65761_row8_col4, #T_65761_row9_col4, #T_65761_row10_col4, #T_65761_row11_col4, #T_65761_row12_col4, #T_65761_row13_col4, #T_65761_row14_col4, #T_65761_row15_col4, #T_65761_row16_col4, #T_65761_row17_col4, #T_65761_row18_col4, #T_65761_row19_col4, #T_65761_row20_col4, #T_65761_row21_col4, #T_65761_row23_col4, #T_65761_row24_col4, #T_65761_row25_col4, #T_65761_row26_col4, #T_65761_row27_col4, #T_65761_row29_col4, #T_65761_row33_col4, #T_65761_row34_col4, #T_65761_row35_col4, #T_65761_row36_col4, #T_65761_row37_col4, #T_65761_row38_col4, #T_65761_row39_col4, #T_65761_row40_col4, #T_65761_row41_col4, #T_65761_row42_col4, #T_65761_row44_col4, #T_65761_row45_col4, #T_65761_row46_col4, #T_65761_row47_col4, #T_65761_row50_col4, #T_65761_row51_col4, #T_65761_row52_col4, #T_65761_row53_col4, #T_65761_row54_col4, #T_65761_row55_col4, #T_65761_row56_col4, #T_65761_row57_col4, #T_65761_row59_col4, #T_65761_row60_col4, #T_65761_row62_col4, #T_65761_row63_col4, #T_65761_row64_col4, #T_65761_row65_col4, #T_65761_row66_col4, #T_65761_row67_col4, #T_65761_row68_col4, #T_65761_row69_col4, #T_65761_row70_col4, #T_65761_row71_col4, #T_65761_row72_col4, #T_65761_row74_col4, #T_65761_row75_col4, #T_65761_row76_col4, #T_65761_row77_col4, #T_65761_row78_col4, #T_65761_row79_col4, #T_65761_row81_col4, #T_65761_row82_col4, #T_65761_row83_col4, #T_65761_row84_col4, #T_65761_row85_col4, #T_65761_row87_col4, #T_65761_row93_col4, #T_65761_row94_col4, #T_65761_row95_col4, #T_65761_row96_col4, #T_65761_row97_col4, #T_65761_row98_col4, #T_65761_row99_col4, #T_65761_row100_col4, #T_65761_row101_col4, #T_65761_row102_col4, #T_65761_row103_col4, #T_65761_row104_col4, #T_65761_row106_col4, #T_65761_row108_col4, #T_65761_row109_col4, #T_65761_row110_col4, #T_65761_row112_col4, #T_65761_row113_col4, #T_65761_row114_col4, #T_65761_row115_col4, #T_65761_row117_col4, #T_65761_row118_col4, #T_65761_row120_col4, #T_65761_row123_col4, #T_65761_row124_col4, #T_65761_row125_col4, #T_65761_row126_col4, #T_65761_row127_col4, #T_65761_row128_col4, #T_65761_row129_col4, #T_65761_row130_col4, #T_65761_row131_col4, #T_65761_row132_col4, #T_65761_row134_col4, #T_65761_row135_col4, #T_65761_row136_col4, #T_65761_row137_col4, #T_65761_row138_col4, #T_65761_row139_col4, #T_65761_row140_col4, #T_65761_row141_col4, #T_65761_row142_col4, #T_65761_row143_col4, #T_65761_row145_col4, #T_65761_row146_col4, #T_65761_row150_col4, #T_65761_row151_col4, #T_65761_row152_col4, #T_65761_row153_col4, #T_65761_row162_col4, #T_65761_row163_col4, #T_65761_row166_col4, #T_65761_row167_col4, #T_65761_row168_col4, #T_65761_row170_col4, #T_65761_row172_col4, #T_65761_row173_col4, #T_65761_row174_col4, #T_65761_row176_col4, #T_65761_row177_col4, #T_65761_row179_col4, #T_65761_row183_col4, #T_65761_row186_col4, #T_65761_row187_col4, #T_65761_row189_col4, #T_65761_row190_col4, #T_65761_row191_col4, #T_65761_row192_col4, #T_65761_row193_col4, #T_65761_row194_col4, #T_65761_row195_col4, #T_65761_row196_col4, #T_65761_row198_col4, #T_65761_row199_col4, #T_65761_row200_col4, #T_65761_row201_col4, #T_65761_row203_col4, #T_65761_row205_col4, #T_65761_row206_col4, #T_65761_row209_col4, #T_65761_row210_col4, #T_65761_row211_col4, #T_65761_row212_col4, #T_65761_row213_col4, #T_65761_row214_col4, #T_65761_row215_col4, #T_65761_row218_col4, #T_65761_row220_col4, #T_65761_row221_col4, #T_65761_row222_col4, #T_65761_row223_col4, #T_65761_row224_col4, #T_65761_row225_col4, #T_65761_row226_col4, #T_65761_row227_col4, #T_65761_row228_col4, #T_65761_row230_col4, #T_65761_row231_col4, #T_65761_row233_col4, #T_65761_row234_col4, #T_65761_row235_col4, #T_65761_row236_col4, #T_65761_row237_col4, #T_65761_row240_col4, #T_65761_row241_col4, #T_65761_row242_col4, #T_65761_row247_col4, #T_65761_row248_col4, #T_65761_row249_col4, #T_65761_row250_col4, #T_65761_row251_col4, #T_65761_row252_col4, #T_65761_row253_col4, #T_65761_row255_col4, #T_65761_row25 ...
#   background-color: #ffffd9;
#   color: #000000;
# }
# #T_65761_row2_col4, #T_65761_row3_col4, #T_65761_row7_col4, #T_65761_row22_col4, #T_65761_row28_col4, #T_65761_row30_col4, #T_65761_row31_col4, #T_65761_row32_col4, #T_65761_row43_col4, #T_65761_row48_col4, #T_65761_row49_col4, #T_65761_row58_col4, #T_65761_row86_col4, #T_65761_row90_col4, #T_65761_row105_col4, #T_65761_row107_col4, #T_65761_row121_col4, #T_65761_row122_col4, #T_65761_row133_col4, #T_65761_row154_col4, #T_65761_row155_col4, #T_65761_row157_col4, #T_65761_row159_col4, #T_65761_row160_col4, #T_65761_row161_col4, #T_65761_row164_col4, #T_65761_row165_col4, #T_65761_row169_col4, #T_65761_row171_col4, #T_65761_row175_col4, #T_65761_row178_col4, #T_65761_row180_col4, #T_65761_row181_col4, #T_65761_row182_col4, #T_65761_row188_col4, #T_65761_row197_col4, #T_65761_row202_col4, #T_65761_row204_col4, #T_65761_row208_col4, #T_65761_row219_col4, #T_65761_row232_col4, #T_65761_row243_col4, #T_65761_row244_col4, #T_65761_row245_col4, #T_65761_row246_col4, #T_65761_row254_col4, #T_65761_row267_col4, #T_65761_row270_col4, #T_65761_row273_col4, #T_65761_row278_col4, #T_65761_row279_col4, #T_65761_row283_col4, #T_65761_row284_col4, #T_65761_row285_col4, #T_65761_row288_col4, #T_65761_row289_col4, #T_65761_row292_col4, #T_65761_row296_col4, #T_65761_row297_col4, #T_65761_row304_col4, #T_65761_row305_col4, #T_65761_row309_col4, #T_65761_row315_col4, #T_65761_row316_col4 {
#   background-color: #feffd8;
#   color: #000000;
# }
# #T_65761_row4_col4, #T_65761_row294_col4, #T_65761_row295_col4 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_65761_row61_col4 {
#   background-color: #f1faba;
#   color: #000000;
# }
# #T_65761_row73_col4, #T_65761_row89_col4, #T_65761_row184_col4, #T_65761_row239_col4 {
#   background-color: #fdfed5;
#   color: #000000;
# }
# #T_65761_row80_col4, #T_65761_row91_col4, #T_65761_row147_col4, #T_65761_row148_col4, #T_65761_row156_col4, #T_65761_row158_col4, #T_65761_row185_col4, #T_65761_row216_col4, #T_65761_row217_col4, #T_65761_row229_col4, #T_65761_row265_col4, #T_65761_row266_col4, #T_65761_row313_col4, #T_65761_row318_col4 {
#   background-color: #feffd6;
#   color: #000000;
# }
# #T_65761_row88_col4, #T_65761_row92_col4 {
#   background-color: #fafdcf;
#   color: #000000;
# }
# #T_65761_row111_col4, #T_65761_row116_col4 {
#   background-color: #f9fdcc;
#   color: #000000;
# }
# #T_65761_row119_col4, #T_65761_row300_col4 {
#   background-color: #fcfed3;
#   color: #000000;
# }
# #T_65761_row144_col4, #T_65761_row298_col4, #T_65761_row299_col4, #T_65761_row301_col4, #T_65761_row302_col4, #T_65761_row323_col4, #T_65761_row330_col4 {
#   background-color: #081d58;
#   color: #f1f1f1;
# }
# #T_65761_row149_col4 {
#   background-color: #f7fcc7;
#   color: #000000;
# }
# #T_65761_row207_col4, #T_65761_row238_col4, #T_65761_row264_col4, #T_65761_row287_col4 {
#   background-color: #fdfed4;
#   color: #000000;
# }
# #T_65761_row303_col4 {
#   background-color: #fbfdd0;
#   color: #000000;
# }
# #T_65761_row327_col4 {
#   background-color: #f8fcc9;
#   color: #000000;
# }
# #T_65761_row328_col4 {
#   background-color: #f5fbc2;
#   color: #000000;
# }
# </style>
# <table id="T_65761">

# %%
ds_v14_3_0.close()
ds_spinup.close()
